# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.13/dist-packages (4.0.4)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /usr/local/lib/python3.13/dist-packages (from pyspark) (0.10.9.9)

# %%
from pyspark.sql import SparkSession
# Create a Spark Session
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Colab_PySpark_Test") \
    .getOrCreate()
# Check to see if it worked
print(spark)
# Out:
# <pyspark.sql.session.SparkSession object at 0x7fabc4fe3230>

# %%
import random
# Access the SparkContext from your SparkSession
sc = spark.sparkContext
num_samples = 100000000
def inside(p):
  x, y = random.random(), random.random()
  return x*x + y*y < 1
# This runs in parallel
count = sc.parallelize(range(0, num_samples)).filter(inside).count()
pi = 4 * count / num_samples
print(f"Pi is roughly {pi}")
# Out:
# Pi is roughly 3.14168116
